# %%
import csv, codecs
import xml.etree.ElementTree as ET

form2lemma = {}
map_tags = {"мн." : "S", "со" : "S", "м" : "S", "ж" : "S", "жо" : "S", "мо" : "S", "мо-жо" : "S", "с" : "S", "п" : "A",
            "числ.-п" : "A", "мс-п" : "A", "нсв" : "V", "св" : "V", "св-нсв" : "V", "предл." : "PR", "союз" : "CONJ", "сравн." : "ADV",
            "н" : "ADV", "вводн." : "ADV", "част." : "ADV", "межд." : "ADV", "предик." : "NI", "числ." : "NI", "мест." : "NI",
            "VERB" : "V", "UNKN" : "NI", "PREP" : "PR", "ADJS" : "A", "ADJF" : "A", "NOUN" : "S", "NPRO" : "NI",
            "PRCL" : "ADV", "ADVB" : "ADV", "CONJ" : "CONJ", "INFN" : "V", "GRND" : "V", "PRTS" : "V", "PRTF" : "V",
            "COMP" : "A", "INTJ" : "ADV", "NUMR" : "NI", "PRED" : "NI", "Prnt" : "ADV"}
freq = {}
freq_lemmas = {}
tags_in_freq = {}

odict_path = 'odict.csv'
opcorpora_annot_path = "annot.opcorpora.no_ambig.nonmod.xml"
opcorpora_dict_path = "dict.opcorpora.xml"

# %%
opcorpora_dict_tree = ET.parse(opcorpora_dict_path)
opcorpora_dict_root = opcorpora_dict_tree.getroot()

# %%
def build_form2lemma_from_odict(odict_path):
    with open(odict_path, encoding="cp1251") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            n = len(row)
            for i in range(n):
                if i == 1:
                    continue
                if row[i] == "":
                    continue
                if row[i] not in form2lemma:
                    form2lemma[row[i]] = []
                if (row[0], row[1]) not in form2lemma[row[i]]:
                    form2lemma[row[i]].append((row[0], row[1]))
            line_count += 1

        print(f'Processed {line_count} lines.')
        print(form2lemma["было"])
        #print(form2lemma["о"])
        #print(form2lemma["обезболивание"])
        #print(form2lemma["времени"])

# %%
def build_for2lemma_from_opcorpora(opcorpora_dict_path):
    #f = codecs.open(opcorpora_dict_path, 'r')
    #u = f.read()
    #print(u[0:80000])

    lemmata = opcorpora_dict_root[2]
    for lemma in lemmata:
        lem = lemma[0].attrib['t']
        tag = lemma[0][0].attrib['v']

        if tag == "PNCT" or tag == "LATN" or tag == "SYMB" or tag == "NUMB" or tag == "ROMN":
            continue

        mapped_tag = map_tags[tag]

        for child in lemma:
            if child.tag == "l":
                continue
            word = child.attrib['t']
            if word not in form2lemma:
                form2lemma[word] = []
            # search for mapped_tag in form2lemma:
            exist = False
            for elem in form2lemma[word]:
                if elem[1] == mapped_tag:
                    exist = True
                    break

            if not exist:
                form2lemma[word].append((lem, mapped_tag))

    #print(form2lemma["ежа"])

# %%
def form2lemma_map_tags():
    for elem in form2lemma:
        num = len(form2lemma[elem])
        for i in range(num):
            if form2lemma[elem][i][1] not in map_tags:
                print(elem)
                print(form2lemma[elem][i][0])
                print(form2lemma[elem][i][1])
                print("________")
                continue
            form2lemma[elem][i] = (form2lemma[elem][i][0], map_tags[form2lemma[elem][i][1]])

    print(form2lemma["конец"])

# %%
def build_freq(opcorpora_annot_path):
    #f = codecs.open(opcorpora_annot_path, 'r')
    #u = f.read()
    #print(u[0:5000])

    tree = ET.parse(opcorpora_annot_path)
    root = tree.getroot()

    #print(root.tag)

    for text in root:
        paragraphs = text[1]
        for paragraph in paragraphs:
            # print(paragraph.tag, paragraph.attrib)
            for sentence in paragraph:
                # print(sentence.tag, sentence.attrib)
                tokens = sentence[1]
                for token in tokens:
                    word = token.attrib['text']
                    lemma = token[0][0][0].attrib['t']
                    tag = token[0][0][0][0].attrib['v']

                    if word == "почти" or word == "Почти":
                        print("EXIST")

                    if tag == "PNCT" or tag == "LATN" or tag == "SYMB" or tag == "NUMB" or tag == "ROMN":
                        continue

                    if tag not in map_tags:
                        print(token.attrib['text'])
                        print(token[0][0][0].attrib['t'])
                        print(token[0][0][0][0].attrib['v'])
                        print("_________________________________")
                        continue

                    mapped_tag = map_tags[tag]

                    if (word, mapped_tag) not in freq:
                        freq[(word, mapped_tag)] = (0, lemma)
                    freq[(word, mapped_tag)] = (freq[(word, mapped_tag)][0] + 1, lemma)

                    if (lemma, mapped_tag) not in freq_lemmas:
                        freq_lemmas[(lemma, mapped_tag)] = 0
                    freq_lemmas[(lemma, mapped_tag)] = freq_lemmas[(lemma, mapped_tag)] + 1

                    if word not in tags_in_freq:
                        tags_in_freq[word] = []
                    if mapped_tag not in tags_in_freq[word]:
                        tags_in_freq[word].append(mapped_tag)

    print(freq[("решения", "S")])
    print(tags_in_freq["сбор"])

# %%
def get_sentences_tokens(dataset_path):
    dataset_file = open(dataset_path, "r")
    raw_text = dataset_file.read()
    sentences = raw_text.split("\n")
    sentences_num = len(sentences)

    print(sentences)

    sentences_tokens = []

    for i in range(sentences_num):
        if sentences[i] == "":
            continue
        sentences[i] = sentences[i].replace(".", "").replace(",", "").replace("?", "").replace("!", "")
        sentences_tokens.append(sentences[i].split(" "))

    print(sentences_tokens)
    return sentences_tokens

# %%
def print_ans_odict_only(sentences_tokens):
    lemmatized_sentences = []

    for s in sentences_tokens:
        res = []
        num = -1
        for token in s:
            num += 1
            if token not in form2lemma:
                right_case_token = token.lower()
            else:
                right_case_token = token

            if right_case_token not in form2lemma:
                if token.isupper():
                    res.append(token + "{" + token + "=" + "S" + "}")
                elif token[0].isupper() and num != 0:
                    res.append(token + "{" + token + "=" + "S" + "}")
                elif num == 0:
                    res.append(token + "{" + token.lower() + "=" + "S" + "}")
                else:
                    res.append(token + "{" + token + "=" + "S" + "}")
                continue

            if len(form2lemma[right_case_token]) == 1:
                if form2lemma[right_case_token][0][1] in map_tags:
                    res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags[
                        form2lemma[right_case_token][0][1]] + "}")
                else:
                    res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + "NI" + "}")
            else:
                added = False

                for pair in form2lemma[right_case_token]:
                    if pair[1] == "союз":
                        res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags["союз"] + "}")
                        added = True
                        break
                    if pair[1] == "предл.":
                        res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags["предл."] + "}")
                        added = True
                        break
                    if pair[1] == "нсв" or pair[1] == "св":
                        res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags["нсв"] + "}")
                        added = True
                        break
                    if pair[1] == "п":
                        res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags["п"] + "}")
                        added = True
                        break

                if added:
                    continue

                if form2lemma[right_case_token][0][1] not in map_tags:
                    print(token)
                    res.append(token)
                else:
                    res.append(token + "{" + form2lemma[right_case_token][0][0] + "=" + map_tags[
                        form2lemma[right_case_token][0][1]] + "}")

        lemmatized_sentences.append(res)

    for lst in lemmatized_sentences:
        ans = " "
        ans = ans.join(lst)
        print(ans)

# %%
def get_most_freq_pair_by_infn(word):
    max_freq = 0
    best_ans = None
    for pair in form2lemma[word]:
        lemma = pair[0]
        tag = pair[1]

        if (lemma, tag) not in freq_lemmas:
            continue
        if freq_lemmas[(lemma, tag)] > max_freq:
            max_freq = freq_lemmas[(lemma, tag)]
            best_ans = (lemma, tag)
    return best_ans

def get_most_freq_pair(word):
    if word not in tags_in_freq:
        return get_most_freq_pair_by_infn(word)
    max_freq = 0
    best_ans = None
    for tag in tags_in_freq[word]:
        cur_freq, lemma = freq[(word, tag)]
        if cur_freq > max_freq:
            max_freq = cur_freq
            best_ans = (lemma, tag)
    return best_ans

# %%
def right_verb_lemma(verb, lemma):
    if verb.endswith("ся") or verb.endswith("сь"):
        if not lemma.endswith("ся"):
            lemma += "ся"
    return lemma

# %%
endings = {"ый" : "ый", "ого" : "ый", "ому" : "ый", "ым" : "ый", "ом" : "ый", 
           "ая" : "ый", "ой" : "ый", "ую" : "ый", "ое" : "ый", "ые" : "ый", "ых" : "ый", "ым" : "ый", 
           "ыми" : "ый", "ых" : "ый", "ий" : "ий", "его" : "ий", "ему" : "ий", "им" : "ий", "ем" : "ий", 
           "яя" : "ий", "ей" : "ий", "юю" : "ий", "ее" : "ий", "ие" : "ий", "их" : "ий", "им" : "ий", "ими" : "ий"}

def if_adj(word):
    if len(word) >= 2 and word[-2:] in endings:
        return True
    if len(word) >= 3 and word[-3:] in endings:
        return True
    return False

def get_adj_lemma(word):
    if len(word) >= 2 and word[-2:] in endings:
        word = word[:-2] + endings[word[-2:]]
    elif len(word) >= 3 and word[-3:] in endings:
        word = word[:-3] + endings[word[-3:]]
    return word

# %%
def find_lemma(word, tag, default):
    lst = form2lemma[word]
    for elem in lst:
        if elem[1] == tag:
            return elem[0]
    return default

def print_ans_dict_and_freq(sentences_tokens):
    lemmatized_sentences = []

    for s in sentences_tokens:
        res = []
        num = -1
        for token in s:
            num += 1
            if token not in form2lemma:
                right_case_token = token.lower()
            else:
                right_case_token = token

            if right_case_token not in form2lemma:
                print(f"Not in dict: {token}")
                if token[0].isupper() and num != 0:
                    res.append(token + "{" + token + "=" + "S" + "}")
                else:    
                    if token in tags_in_freq:
                        best_pair = get_most_freq_pair(token)
                        lemma = best_pair[0]
                        tag = best_pair[1]
                        if tag == "V":
                            lemma = right_verb_lemma(token, lemma)
                            
                        res.append(token + "{" + lemma + "=" + tag + "}")
                        continue
                    
                    lower_case_token = token.lower()
                    if lower_case_token in tags_in_freq:
                        best_pair = get_most_freq_pair(lower_case_token)
                        lemma = best_pair[0]
                        tag = best_pair[1]
                        if tag == "V":
                            lemma = right_verb_lemma(lower_case_token, lemma)
                            
                        res.append(token + "{" + lemma + "=" + tag + "}")
                        continue
                        
                    if if_adj(lower_case_token):
                        res.append(token + "{" + get_adj_lemma(lower_case_token) + "=" + "A" + "}")
                        print(get_adj_lemma(lower_case_token))
                        continue

                    res.append(token + "{" + lower_case_token + "=" + "S" + "}")
                continue

            if len(form2lemma[right_case_token]) == 1:
                lemma = form2lemma[right_case_token][0][0]
                tag = form2lemma[right_case_token][0][1]
                if tag == "V":
                    lemma = right_verb_lemma(right_case_token, lemma)
                
                res.append(token + "{" + lemma + "=" + tag + "}")
            else:
                best_pair = get_most_freq_pair(right_case_token)
                if best_pair != None:
                    right_lemma = find_lemma(right_case_token, best_pair[1], best_pair[0])
                    
                    lemma = right_lemma
                    tag = best_pair[1]
                    if tag == "V":
                        lemma = right_verb_lemma(right_case_token, lemma)
                    
                    res.append(token + "{" + lemma + "=" + tag + "}")
                    continue

                added = False
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "CONJ":
                        res.append(token + "{" + pair[0] + "=" + "CONJ" + "}")
                        added = True
                        break
                if added:
                    continue
                        
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "PR":
                        res.append(token + "{" + pair[0] + "=" + "PR" + "}")
                        added = True
                        break
                if added:
                    continue        
                
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "V":
                        lemma = pair[0]
                        lemma = right_verb_lemma(right_case_token, lemma)
                        
                        res.append(token + "{" + lemma + "=" + "V" + "}")
                        added = True
                        break
                if added:
                    continue
                
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "A":
                        res.append(token + "{" + pair[0] + "=" + "A" + "}")
                        added = True
                        break
                if added:
                    continue
                
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "ADV":
                        res.append(token + "{" + pair[0] + "=" + "ADV" + "}")
                        added = True
                        break
                if added:
                    continue
                    
                for pair in form2lemma[right_case_token]:
                    if pair[1] == "S":
                        res.append(token + "{" + pair[0] + "=" + "S" + "}")
                        added = True
                        break
                if added:
                    continue

                # choose random lemma (first lemma)
                lemma = form2lemma[right_case_token][0][0]
                tag = form2lemma[right_case_token][0][1] 
                if tag == "V":
                    lemma = right_verb_lemma(right_case_token, lemma)
                res.append(token + "{" + lemma + "=" + tag + "}")

        lemmatized_sentences.append(res)

    for lst in lemmatized_sentences:
        ans = " "
        ans = ans.join(lst)
        print(ans)

# %%
#f = codecs.open(odict_path, 'r', 'cp1251')
#u = f.read()

#ind = u.find(",н,")
#print(u[0:1000])

build_form2lemma_from_odict(odict_path)
form2lemma_map_tags()

build_for2lemma_from_opcorpora(opcorpora_dict_path)

build_freq(opcorpora_annot_path)

#print(form2lemma["почти"])
#print(tags_in_freq["почти"])
# Out:
# Processed 102498 lines.
# [('было', 'част.')]
# [('конец', 'S')]
# (56, 'решение')
# ['S']

# %%
form2lemma["быть"] = [("быть", "V")]
form2lemma["был"] = [("быть", "V")]
form2lemma["была"] = [("быть", "V")]
form2lemma["были"] = [("быть", "V")]
form2lemma["было"] = [("быть", "V")]
form2lemma["буду"] = [("быть", "V")]
form2lemma["будет"] = [("быть", "V")]
form2lemma["будут"] = [("быть", "V")]

# %%
dataset_path = "dataset_37845_55.txt"
#dataset_path = "test.txt"

sentences_tokens = get_sentences_tokens(dataset_path)

print_ans_dict_and_freq(sentences_tokens)
# Out:
# ['И это не удивительно, поскольку на самом деле это не настоящие лепестки, а разросшиеся чашелистики.', 'Ряд предложений Н. Я. Виленкина требует дополнительных разъяснений и уточнений.', 'После сырого, холодящего ноги, северного склона приятно снова ступать по сухим, мягким листьям.', 'Возможности мультимедийных технологий так и остаются до сих пор потенциальными, их освоение и использование для дидактических целей идёт медленно и едва ли будет идти быстрее, чем освоение возможностей преждевременно скончавшегося обычного печатного слова.', 'Изучая его указания, сопровождавшиеся иногда мелкими набросками, нельзя не удивляться самостоятельности его градостроительной концепции.', 'Они вошли в лес, и сразу ещё сильнее запахло смолой и хвоей.', 'Я ответил, что тут всё стихи, только переведены они прозой.', 'Разумеется, ему пока трудно это делать, но главное, чтобы у малыша вырабатывалось стремление к чистоте.', 'Кваша сразу понял, что это про него, и не раздумывая сделал шаг вперёд.', 'Такие нетканые полотна нашли наибольшее применение для производства медицинских материалов и изделий, для впитывающих салфеток и тампонов, хирургических простыней и халатов, одежды медперсонала.', 'Конечно, если бы я не был заместителем председателя Думы, я бы сказал всё, что я думаю по данному вопросу, а сейчас я этого не говорю.', 'И когда он обнял, прижал к себе, тёплому, её стала бить дрожь.', 'Железная дорога незаменима в тех случаях, когда надо обеспечить перевозки большого количества пассажиров в короткое время и относительно дёшево.', 'Поэтому платить НДС со всей суммы реализации в вашем случае не требуется.', 'Лингвистика свидетельствует о контактах славян в это время с западными балтами, германцами и скифами.', 'Это означало, что надлежит сходить в магазин для покупки молока и хлеба.', 'Для животных, не умеющих поддерживать постоянную температуру тела, проще всего подыскать для себя тёплое убежище.', 'Помню его ещё молодым красавцем с пышной причёской, всегда окружённым восторженными поклонницами, славой и сплетнями.', 'В последние годы именно возможности современных информационных технологий позволили большинству стран, в том числе и России, поставить задачи по осуществлению значительных преобразований почтовых систем.', 'Но потом оказалось, что не понимает ясных и скучных вещей, объяснять каждый раз было тягостно, лучше молчать, молчали утром, днём, вечером, когда ложились спать, когда ехали в поезде, в двухместном купе.', 'Мягко ступая на носках, как будто крадучись, ко мне подошёл Кошачий Зуб.', 'Рябчук направлялся к военной машине, без шапки, с поцарапанным лицом.', 'Значит, уже нельзя любить и жалеть её, как собиралась ночью.', 'Потому что я нахожусь в женском окружении и эти замечательные дамы пытаются меня убедить.', 'Если перейти к вопросам не менее важным, таким, как вопросы безопасности в самом широком смысле слова, то здесь существуют очень серьёзные проблемы, которые правительство не в состоянии решить.', 'Однако у части научного сообщества сложилось мнение, что работа в этой области является ремеслом, недостойным настоящего учёного.', 'Так что ни в коем случае не отказывайте себе в удовольствии полакомиться вкусными и полезными орешками.', 'И работать, в конечном счёте, он будет на наши интересы, на настоящее и будущее Кубани и её жителей.', 'Именно против них должны быть направлены все имеющиеся в нашем распоряжении силы и средства.', 'Мы предложили партнерство ОНЭКСИМу и принялись вместе с ним скупать акции мелких владельцев.', 'Его важнейшей особенностью является гораздо меньшая степень сокращения размеров занятости по отношению к сокращению объёмов производства, а также компенсация сокращения возникшей разницы за счёт сокращения заработной платы.', 'Потому что пришлось изменить конституцию, чтобы внедрить в неё принцип равенства, полного равенства приоритетов в политике.', 'Она решила пойти в садоводство, попытаться достать там хоть немного цветов.', 'Когда к Лагарпову пришла старость, он стал всё чаще задумываться.', 'В н ...
# [['И', 'это', 'не', 'удивительно', 'поскольку', 'на', 'самом', 'деле', 'это', 'не', 'настоящие', 'лепестки', 'а', 'разросшиеся', 'чашелистики'], ['Ряд', 'предложений', 'Н', 'Я', 'Виленкина', 'требует', 'дополнительных', 'разъяснений', 'и', 'уточнений'], ['После', 'сырого', 'холодящего', 'ноги', 'северного', 'склона', 'приятно', 'снова', 'ступать', 'по', 'сухим', 'мягким', 'листьям'], ['Возможности', 'мультимедийных', 'технологий', 'так', 'и', 'остаются', 'до', 'сих', 'пор', 'потенциальными', 'их', 'освоение', 'и', 'использование', 'для', 'дидактических', 'целей', 'идёт', 'медленно', 'и', 'едва', 'ли', 'будет', 'идти', 'быстрее', 'чем', 'освоение', 'возможностей', 'преждевременно', 'скончавшегося', 'обычного', 'печатного', 'слова'], ['Изучая', 'его', 'указания', 'сопровождавшиеся', 'иногда', 'мелкими', 'набросками', 'нельзя', 'не', 'удивляться', 'самостоятельности', 'его', 'градостроительной', 'концепции'], ['Они', 'вошли', 'в', 'лес', 'и', 'сразу', 'ещё', 'сильнее', 'запахло', 'смолой', 'и', 'хвоей'], ['Я', 'ответил', 'что', 'тут', 'всё', 'стихи', 'только', 'переведены', 'они', 'прозой'], ['Разумеется', 'ему', 'пока', 'трудно', 'это', 'делать', 'но', 'главное', 'чтобы', 'у', 'малыша', 'вырабатывалось', 'стремление', 'к', 'чистоте'], ['Кваша', 'сразу', 'понял', 'что', 'это', 'про', 'него', 'и', 'не', 'раздумывая', 'сделал', 'шаг', 'вперёд'], ['Такие', 'нетканые', 'полотна', 'нашли', 'наибольшее', 'применение', 'для', 'производства', 'медицинских', 'материалов', 'и', 'изделий', 'для', 'впитывающих', 'салфеток', 'и', 'тампонов', 'хирургических', 'простыней', 'и', 'халатов', 'одежды', 'медперсонала'], ['Конечно', 'если', 'бы', 'я', 'не', 'был', 'заместителем', 'председателя', 'Думы', 'я', 'бы', 'сказал', 'всё', 'что', 'я', 'думаю', 'по', 'данному', 'вопросу', 'а', 'сейчас', 'я', 'этого', 'не', 'говорю'], ['И', 'когда', 'он', 'обнял', 'прижал', 'к', 'себе', 'тёплому', 'её', 'стала', 'бить', 'дрожь'], ['Железная', 'дорога', 'незаменима', 'в', 'тех', 'случаях', 'когда', 'надо', 'обеспечить', 'перевозки', 'большого', 'количества', 'пассажиров', 'в', 'короткое', 'время', 'и', 'относительно', 'дёшево'], ['Поэтому', 'платить', 'НДС', 'со', 'всей', 'суммы', 'реализации', 'в', 'вашем', 'случае', 'не', 'требуется'], ['Лингвистика', 'свидетельствует', 'о', 'контактах', 'славян', 'в', 'это', 'время', 'с', 'западными', 'балтами', 'германцами', 'и', 'скифами'], ['Это', 'означало', 'что', 'надлежит', 'сходить', 'в', 'магазин', 'для', 'покупки', 'молока', 'и', 'хлеба'], ['Для', 'животных', 'не', 'умеющих', 'поддерживать', 'постоянную', 'температуру', 'тела', 'проще', 'всего', 'подыскать', 'для', 'себя', 'тёплое', 'убежище'], ['Помню', 'его', 'ещё', 'молодым', 'красавцем', 'с', 'пышной', 'причёской', 'всегда', 'окружённым', 'восторженными', 'поклонницами', 'славой', 'и', 'сплетнями'], ['В', 'последние', 'годы', 'именно', 'возможности', 'современных', 'информационных', 'технологий', 'позволили', 'большинству', 'стран', 'в', 'том', 'числе', 'и', 'России', 'поставить', 'задачи', 'по', 'осуществлению', 'значительных', 'преобразований', 'почтовых', 'систем'], ['Но', 'потом', 'оказалось', 'что', 'не', 'понимает', 'ясных', 'и', 'скучных', 'вещей', 'объяснять', 'каждый', 'раз', 'было', 'тягостно', 'лучше', 'молчать', 'молчали', 'утром', 'днём', 'вечером', 'когда', 'ложились', 'спать', 'когда', 'ехали', 'в', 'поезде', 'в', 'двухместном', 'купе'], ['Мягко', 'ступая', 'на', 'носках', 'как', 'будто', 'крадучись', 'ко', 'мне', 'подошёл', 'Кошачий', 'Зуб'], ['Рябчук', 'направлялся', 'к', 'военной', 'машине', 'без', 'шапки', 'с', 'поцарапанным', 'лицом'], ['Значит', 'уже', 'нельзя', 'любить', 'и', 'жалеть', 'её', 'как', 'собиралась', 'ночью'], ['Потому', 'что', 'я', 'нахожусь', 'в', 'женском', 'окружении', 'и', 'эти', 'замечательные', 'дамы', 'пытаются', 'меня', 'убедить'], ['Если', 'перейти', 'к', 'вопросам', 'не', 'менее', 'важным', 'таким', 'как', 'вопросы', 'безопасности', 'в', 'самом', 'широком', 'смысле', 'слова', 'то', 'здесь', 'существуют', 'очень', 'сер ...
# Not in dict: Виленкина
# Not in dict: балтами
# Not in dict: партнерство
# Not in dict: ОНЭКСИМу
# Not in dict: Кайоль
# Not in dict: фруской
# фрускый
# Not in dict: оглядываний
# оглядываний
# Not in dict: безусловнорефлекторные
# безусловнорефлекторный
# Not in dict: ОПВ
# Not in dict: флораты
# Not in dict: Терехово
# Not in dict: Гисена
# Not in dict: Вийона
# Not in dict: Шкап
# Not in dict: мамалыжной
# мамалыжный
# Not in dict: радиоастроном
# радиоастроный
# Not in dict: Дрэйк
# Not in dict: неоинституциональной
# неоинституциональный
# Not in dict: ребенка
# Not in dict: Матрену
# Not in dict: ОЮЛ
# Not in dict: сопом
# сопый
# Not in dict: безотчетно
# Not in dict: полуразвалившегося
# Not in dict: Шамординского
# Not in dict: старлей
# старлий
# Not in dict: Калигула
# Not in dict: лоцируемого
# лоцируемый
# И{и=CONJ} это{это=NI} не{не=ADV} удивительно{удивительный=A} поскольку{поскольку=CONJ} на{на=PR} самом{самый=A} деле{дело=S} это{это=NI} не{не=ADV} настоящие{настоящий=A} лепестки{лепесток=S} а{а=CONJ} разросшиеся{разрастисься=V} чашелистики{чашелистик=S}
# Ряд{ряд=S} предложений{предложение=S} Н{н=A} Я{я=NI} Виленкина{Виленкина=S} требует{требовать=V} дополнительных{дополнительный=A} разъяснений{разъяснение=S} и{и=CONJ} уточнений{уточнение=S}
# После{после=PR} сырого{сырой=A} холодящего{холодить=V} ноги{нога=S} северного{северный=A} склона{склон=S} приятно{приятно=ADV} снова{снова=ADV} ступать{ступать=V} по{по=PR} сухим{сухой=A} мягким{мягкий=A} листьям{лист=S}
# Возможности{возможность=S} мультимедийных{мультимедийный=A} технологий{технология=S} так{так=ADV} и{и=CONJ} остаются{оставаться=V} до{до=PR} сих{сей=A} пор{пора=S} потенциальными{потенциальный=A} их{их=A} освоение{освоение=S} и{и=CONJ} использование{использование=S} для{для=PR} дидактических{дидактический=A} целей{цель=S} идёт{идти=V} медленно{медленно=ADV} и{и=CONJ} едва{едва=ADV} ли{ли=ADV} будет{быть=V} идти{идти=V} быстрее{быстрый=A} чем{чем=CONJ} освоение{освоение=S} возможностей{возможность=S} преждевременно{преждевременный=A} скончавшегося{скончаться=V} обычного{обычный=A} печатного{печатный=A} слова{слово=S}
# Изучая{изучать=V} его{его=A} указания{указание=S} сопровождавшиеся{сопровождаться=V} иногда{иногда=ADV} мелкими{мелкий=A} набросками{набросок=S} нельзя{нельзя=NI} не{не=ADV} удивляться{удивляться=V} самостоятельности{самостоятельность=S} его{его=A} градостроительной{градостроительный=A} концепции{концепция=S}
# Они{они=NI} вошли{войти=V} в{в=PR} лес{лес=S} и{и=CONJ} сразу{сразу=ADV} ещё{ещё=ADV} сильнее{сильный=A} запахло{запахнуть=V} смолой{смола=S} и{и=CONJ} хвоей{хвоя=S}
# Я{я=NI} ответил{ответить=V} что{что=CONJ} тут{тут=ADV} всё{весь=A} стихи{стих=S} только{только=ADV} переведены{перевести=V} они{они=NI} прозой{проза=S}
# Разумеется{разумеется=CONJ} ему{он=NI} пока{пока=ADV} трудно{трудно=ADV} это{это=NI} делать{делать=V} но{но=CONJ} главное{главный=A} чтобы{чтобы=CONJ} у{у=PR} малыша{малыш=S} вырабатывалось{вырабатываться=V} стремление{стремление=S} к{к=PR} чистоте{чистота=S}
# Кваша{кваша=S} сразу{сразу=ADV} понял{понять=V} что{что=CONJ} это{это=NI} про{про=PR} него{он=NI} и{и=CONJ} не{не=ADV} раздумывая{раздумывать=V} сделал{сделать=V} шаг{шаг=S} вперёд{вперёд=ADV}
# Такие{такой=A} нетканые{нетканый=A} полотна{полотно=S} нашли{найти=V} наибольшее{наибольший=A} применение{применение=S} для{для=PR} производства{производство=S} медицинских{медицинский=A} материалов{материал=S} и{и=CONJ} изделий{изделие=S} для{для=PR} впитывающих{впитывать=V} салфеток{салфетка=S} и{и=CONJ} тампонов{тампон=S} хирургических{хирургический=A} простыней{простыня=S} и{и=CONJ} халатов{халат=S} одежды{одежда=S} медперсонала{медперсонал=S}
# Конечно{конечно=CONJ} если{если=CONJ} бы{бы=ADV} я{я=NI} не{не=ADV} был{быть=V} заместителем{заместитель=S} председателя{председатель=S} Думы{дума=S} я{я=NI} бы{бы=ADV} сказал{сказать=V} всё{весь=A} что{что=CONJ} я{я=NI} думаю{думать=V} по{по=PR} данному{данный=A} вопросу{вопрос=S} а{а=CONJ} сейчас{сейчас=ADV} я{я=NI} этого{это=NI} не{не=ADV} говорю{говорить=V}
# И{и=CONJ} когда{когда=CONJ} он{он=NI} обнял{обнять=V} прижал{прижать=V} к{к=PR} себе{себя=NI} тёплому{тёплый=A} её{её=A} стала{стать=V} бить{бить=V} дрожь{дрожь=S}
# Железная{железный=A} дорога{дорога=S} незаменима{незаменимый=A} в{в=PR} тех{тот=A} случаях{случай=S} когда{когда=CONJ} надо{надо=NI} обеспечить{обеспечить=V} перевозки{перевозка=S} большого{большой=A} количества{количество=S} пассажиров{пассажир=S} в{в=PR} короткое{короткий=A} время{время=S} и{и=CONJ} относительно{относительно=PR} дёшево{дёшево=ADV}
# Поэтому{поэтому=ADV} платить{платить=V} НДС{ндс=S} со{со=PR} всей{весь=A} суммы{сумма=S} реализации{реализация=S} в{в=PR} вашем{ваш=A} случае{случай=S} не{не=ADV} требуется{требоваться=V}
# Лингвистика{лингвистика=S} свидетельствует{свидетельствовать=V} о{о=PR} контактах{контакт=S} славян{славянин=S} в{в=PR} это{это=NI} время{время=S} с{с=PR} западными{западный=A} балтами{балтами=S} германцами{германец=S} и{и=CONJ} скифами{скиф=S}
# Это{это=NI} означало{означать=V} что{что=CONJ} надлежит{надлежать=V} сходить{сходить=V} в{в=PR} магазин{магазин=S} для{для=PR} покупки{покупка=S} молока{молока=S} и{и=CONJ} хлеба{хлеб=S}
# Для{для=PR} животных{животное=S} не{не=ADV} умеющих{уметь=V} поддерживать{поддерживать=V} постоянную{постоянный=A} температуру{температура=S} тела{тело=S} проще{простой=A} всего{весь=A} подыскать{подыскать=V} для{для=PR} себя{себя=NI} тёплое{тёплый=A} убежище{убежище=S}
# Помню{помнить=V} его{его=A} ещё{ещё=ADV} молодым{молодой=A} красавцем{красавец=S} с{с=PR} пышной{пышный=A} причёской{причёска=S} всегда{всегда=ADV} окружённым{окружить=V} восторженными{восторженный=A} поклонницами{поклонница=S} славой{слава=S} и{и=CONJ} сплетнями{сплетня=S}
# В{в=PR} последние{последний=A} годы{год=S} именно{именно=ADV} возможности{возможность=S} современных{современный=A} информационных{информационный=A} технологий{технология=S} позволили{позволить=V} большинству{большинство=S} стран{страна=S} в{в=PR} том{тот=A} числе{число=S} и{и=CONJ} России{Россия=S} поставить{поставить=V} задачи{задача=S} по{по=PR} осуществлению{осуществление=S} значительных{значительный=A} преобразований{преобразование=S} почтовых{почтовый=A} систем{система=S}
# Но{но=CONJ} потом{потом=ADV} оказалось{оказаться=V} что{что=CONJ} не{не=ADV} понимает{понимать=V} ясных{ясный=A} и{и=CONJ} скучных{скучный=A} вещей{вещь=S} объяснять{объяснять=V} каждый{каждый=A} раз{раз=S} было{быть=V} тягостно{тягостный=A} лучше{хороший=A} молчать{молчать=V} молчали{молчать=V} утром{утром=ADV} днём{день=S} вечером{вечером=ADV} когда{когда=CONJ} ложились{ложиться=V} спать{спать=V} когда{когда=CONJ} ехали{еду=V} в{в=PR} поезде{поезд=S} в{в=PR} двухместном{двухместный=A} купе{купа=S}
# Мягко{мягко=ADV} ступая{ступать=V} на{на=PR} носках{носка=S} как{как=ADV} будто{будто=CONJ} крадучись{крадучись=ADV} ко{ко=PR} мне{я=NI} подошёл{подойти=V} Кошачий{кошачий=A} Зуб{зуб=S}
# Рябчук{рябчук=S} направлялся{направляться=V} к{к=PR} военной{военный=A} машине{машина=S} без{без=PR} шапки{шапка=S} с{с=PR} поцарапанным{поцарапать=V} лицом{лицо=S}
# Значит{значит=CONJ} уже{уже=ADV} нельзя{нельзя=NI} любить{любить=V} и{и=CONJ} жалеть{жалеть=V} её{её=A} как{как=ADV} собиралась{собираться=V} ночью{ночью=ADV}
# Потому{потому=ADV} что{что=CONJ} я{я=NI} нахожусь{находиться=V} в{в=PR} женском{женский=A} окружении{окружение=S} и{и=CONJ} эти{этот=A} замечательные{замечательный=A} дамы{дама=S} пытаются{пытаться=V} меня{я=NI} убедить{убедить=V}
# Если{если=CONJ} перейти{перейти=V} к{к=PR} вопросам{вопрос=S} не{не=ADV} менее{менее=ADV} важным{важный=A} таким{такой=A} как{как=ADV} вопросы{вопрос=S} безопасности{безопасность=S} в{в=PR} самом{самый=A} широком{широкий=A} смысле{смысл=S} слова{слово=S} то{то=CONJ} здесь{здесь=ADV} существуют{существовать=V} очень{очень=ADV} серьёзные{серьёзный=A} проблемы{проблема=S} которые{который=A} правительство{правительство=S} не{не=ADV} в{в=PR} состоянии{состояние=S} решить{решить=V}
# Однако{однако=CONJ} у{у=PR} части{часть=S} научного{научный=A} сообщества{сообщество=S} сложилось{сложиться=V} мнение{мнение=S} что{что=CONJ} работа{работа=S} в{в=PR} этой{этот=A} области{область=S} является{являться=V} ремеслом{ремесло=S} недостойным{недостойный=A} настоящего{настоящий=A} учёного{учёный=S}
# Так{так=ADV} что{что=CONJ} ни{ни=ADV} в{в=PR} коем{кой=A} случае{случай=S} не{не=ADV} отказывайте{отказывать=V} себе{себя=NI} в{в=PR} удовольствии{удовольствие=S} полакомиться{полакомиться=V} вкусными{вкусный=A} и{и=CONJ} полезными{полезный=A} орешками{орешек=S}
# И{и=CONJ} работать{работать=V} в{в=PR} конечном{конечный=A} счёте{счёт=S} он{он=NI} будет{быть=V} на{на=PR} наши{наш=A} интересы{интерес=S} на{на=PR} настоящее{настоящий=A} и{и=CONJ} будущее{будущее=S} Кубани{Кубань=S} и{и=CONJ} её{её=A} жителей{житель=S}
# Именно{именно=ADV} против{против=PR} них{они=NI} должны{должен=A} быть{быть=V} направлены{направить=V} все{весь=A} имеющиеся{иметься=V} в{в=PR} нашем{наш=A} распоряжении{распоряжение=S} силы{сила=S} и{и=CONJ} средства{средства=S}
# Мы{мы=NI} предложили{предложить=V} партнерство{партнёрство=S} ОНЭКСИМу{ОНЭКСИМу=S} и{и=CONJ} принялись{приняться=V} вместе{вместе=ADV} с{с=PR} ним{он=NI} скупать{скупать=V} акции{акция=S} мелких{мелкий=A} владельцев{владелец=S}
# Его{его=A} важнейшей{важнейший=A} особенностью{особенность=S} является{являться=V} гораздо{гораздо=ADV} меньшая{меньший=A} степень{степень=S} сокращения{сокращение=S} размеров{размер=S} занятости{занятость=S} по{по=PR} отношению{отношение=S} к{к=PR} сокращению{сокращение=S} объёмов{объём=S} производства{производство=S} а{а=CONJ} также{также=ADV} компенсация{компенсация=S} сокращения{сокращение=S} возникшей{возникнуть=V} разницы{разница=S} за{за=PR} счёт{счёт=S} сокращения{сокращение=S} заработной{заработный=A} платы{плат=S}
# Потому{потому=ADV} что{что=CONJ} пришлось{прийтисься=V} изменить{изменить=V} конституцию{конституция=S} чтобы{чтобы=CONJ} внедрить{внедрить=V} в{в=PR} неё{она=NI} принцип{принцип=S} равенства{равенство=S} полного{полный=A} равенства{равенство=S} приоритетов{приоритет=S} в{в=PR} политике{политик=S}
# Она{она=NI} решила{решить=V} пойти{пойти=V} в{в=PR} садоводство{садоводство=S} попытаться{попытаться=V} достать{достать=V} там{там=ADV} хоть{хоть=ADV} немного{немного=ADV} цветов{цвет=S}
# Когда{когда=CONJ} к{к=PR} Лагарпову{лагарпов=S} пришла{прийти=V} старость{старость=S} он{он=NI} стал{стать=V} всё{весь=A} чаще{частый=A} задумываться{задумываться=V}
# В{в=PR} настоящей{настоящий=A} работе{работа=S} упор{упор=S} делается{делаться=V} именно{именно=ADV} на{на=PR} междисциплинарный{междисциплинарный=A} подход{подход=S} в{в=PR} решении{решение=S} вопросов{вопрос=S} раннего{ранний=A} этногенеза{этногенез=S} славян{славянин=S} но{но=CONJ} канву{канва=S} изложения{изложение=S} образуют{образовать=V} материалы{материал=S} археологии{археология=S} и{и=CONJ} лингвистики{лингвистика=S}
# Тут{тут=ADV} и{и=CONJ} Коля{Коля=S} явился{явиться=V} неся{нестися=V} через{через=PR} плечо{плечо=S} сетку{сетка=S} полную{полный=A} весело{весело=ADV} гремящих{греметь=V} бутылок{бутылка=S}
# Такое{такой=A} может{мочь=V} быть{быть=V} только{только=ADV} в{в=PR} случае{случай=S} если{если=CONJ} они{они=NI} заведомо{заведомо=ADV} составили{составить=V} себе{себя=NI} неадекватный{неадекватный=A} план{план=S}
# Это{это=NI} хорошо{хороший=A} потому{потому=ADV} что{что=CONJ} Джордж{Джордж=S} Джорджевич{Джордж=S} подпишет{подписать=V} с{с=PR} нами{мы=NI} договор{договор=S} о{о=PR} сокращении{сокращение=S} наступательных{наступательный=A} вооружений{вооружение=S} и{и=CONJ} тем{тот=A} снизит{снизить=V} опасность{опасность=S} ядерной{ядерный=A} войны{война=S} между{между=PR} нами{мы=NI}
# Демократия{демократия=S} которая{который=A} лишает{лишать=V} себя{себя=NI} вклада{вклад=S} который{который=A} может{мочь=V} внести{внести=V} женщина{женщина=S} это{это=NI} незаконченная{незаконченный=A} демократия{демократия=S}
# Ты{ты=NI} же{же=ADV} знаешь{знать=V} где{где=ADV} я{я=NI} был{быть=V} что{что=CONJ} видел{вижу=V} и{и=CONJ} какой{какой=A} жареный{жареный=A} петух{петух=S} меня{я=NI} клевал{клевать=V} в{в=PR} задницу{задница=S}
# Удобно{удобный=A} запекать{запекать=V} несколько{несколько=NI} отдельно{отдельно=ADV} завёрнутых{завернуть=V} порций{порция=S} мяса{мясо=S} птицы{птица=S} рыбы{рыба=S} прямо{прямой=A} с{с=PR} гарниром{гарнир=S}
# Адвокаты{адвокат=S} творят{творить=V} что{что=CONJ} хотят{хотеть=V} и{и=CONJ} закон{закон=S} для{для=PR} них{они=NI} не{не=ADV} писан{писать=V}
# Он{он=NI} увидел{увидеть=V} бы{бы=ADV} что{что=CONJ} в{в=PR} одном{один=A} направлении{направление=S} эти{этот=A} мировые{мировой=A} линии{линия=S} сходятся{сходиться=V} а{а=CONJ} в{в=PR} противоположном{противоположный=A} расходятся{расходиться=V}
# Ну{ну=ADV} сколько{сколько=NI} я{я=NI} видел{вижу=V} подобных{подобный=A} игрушек{игрушка=S} а{а=CONJ} об{об=PR} утюге{утюг=S} не{не=ADV} подумал{подумать=V}
# Это{это=NI} же{же=ADV} замечание{замечание=S} относится{относиться=V} и{и=CONJ} к{к=PR} данным{данные=S} о{о=PR} внутрирегиональных{внутрирегиональный=A} мигрантах{мигрант=S}
# Чувствовать{чувствовать=V} свою{свой=A} красоту{красота=S} ему{он=NI} было{быть=V} так{так=ADV} же{же=ADV} естественно{естественный=A} как{как=ADV} дышать{дышать=V} воздухом{воздух=S}
# В{в=PR} пути{путь=S} их{их=A} ждут{ждать=V} привалы{привал=S} на{на=PR} живописных{живописный=A} лесных{лесной=A} полянах{поляна=S} и{и=CONJ} вкусный{вкусный=A} обед{обед=S} приготовленный{приготовить=V} на{на=PR} костре{костёр=S}
# То{то=CONJ} есть{есть=V} во{во=PR} французском{французский=A} Монреале{монреаль=S} Камилла{Камилла=S} Андреевна{Андреевна=S} Кайоль{Кайоль=S} тоже{тоже=ADV} остаётся{оставаться=V} фруской{фрускый=A}
# Гравийное{гравийный=A} покрытие{покрытие=S} пара{пар=S} валунов{валун=S} и{и=CONJ} бамбуковая{бамбуковый=A} ширма{ширма=S} внесут{внести=V} необходимый{необходимый=A} колорит{колорит=S}
# То{то=CONJ} есть{есть=V} у{у=PR} меня{я=NI} не{не=ADV} было{быть=V} этого{это=NI} последнего{последний=A} из{из=PR} него{он=NI} ухода{уход=S} состоящего{состоять=V} из{из=PR} растерянности{растерянность=S} и{и=CONJ} прощальных{прощальный=A} оглядываний{оглядываний=A} со{со=PR} значением{значение=S} когда{когда=CONJ} желают{желать=V} запомнить{запомнить=V} особо{особо=ADV} и{и=CONJ} почувствовать{почувствовать=V} больше{большой=A} чем{чем=CONJ} отпущено{отпустить=V}
# Каждое{каждый=A} офисное{офисный=A} приложение{приложение=S} сегодня{сегодня=ADV} представляет{представлять=V} собой{себя=NI} систему{система=S} способную{способный=A} интерпретировать{интерпретировать=V} и{и=CONJ} выполнять{выполнять=V} программные{программный=A} коды{код=S}
# Для{для=PR} того{тот=A} чтобы{чтобы=CONJ} произошло{произойти=V} выделение{выделение=S} высоты{высота=S} воздействие{воздействие=S} звукового{звуковой=A} комплекса{комплекс=S} на{на=PR} орган{орган=S} слуха{слух=S} должны{должен=A} вызывать{вызывать=V} не{не=ADV} только{только=ADV} безусловнорефлекторные{безусловнорефлекторный=A} ориентировочные{ориентировочный=A} и{и=CONJ} адаптационные{адаптационный=A} реакции{реакция=S} но{но=CONJ} обязательна{обязательный=A} также{также=ADV} и{и=CONJ} деятельность{деятельность=S} вокального{вокальный=A} аппарата{аппарат=S}
# При{при=PR} этом{это=NI} следует{следовать=V} иметь{иметь=V} в{в=PR} виду{вид=S} что{что=CONJ} бортовая{бортовой=A} радиоаппаратура{радиоаппаратура=S} по{по=PR} ряду{ряд=S} естественных{естественный=A} причин{причина=S} будет{быть=V} малогабаритной{малогабаритный=A} и{и=CONJ} маломощной{маломощный=A}
# Символ{символ=S} же{же=ADV} и{и=CONJ} в{в=PR} плане{план=S} выражения{выражение=S} и{и=CONJ} в{в=PR} плане{план=S} содержания{содержание=S} всегда{всегда=ADV} представляет{представлять=V} собой{себя=NI} некоторый{некоторый=A} текст{текст=S} т{так=ADV} е{есть=V} обладает{обладать=V} некоторым{некоторый=A} единым{единый=A} замкнутым{замкнуть=V} в{в=PR} себе{себя=NI} значением{значение=S} и{и=CONJ} отчётливо{отчётливый=A} выраженной{выразить=V} границей{граница=S} позволяющей{позволять=V} ясно{ясно=ADV} выделить{выделить=V} его{его=A} из{из=PR} окружающего{окружающий=A} семиотического{семиотический=A} контекста{контекст=S}
# Боже{бог=S} мой{мой=A} сама{сам=A} по{по=PR} себе{себя=NI} любовь{любовь=S} к{к=PR} музыке{музыка=S} ничего{ничего=ADV} не{не=ADV} говорит{говорить=V} о{о=PR} человеке{человек=S}
# Я{я=NI} никогда{никогда=ADV} не{не=ADV} шиковала{шиковать=V} и{и=CONJ} теперь{теперь=ADV} все{весь=A} деньги{деньга=S} трачу{тратить=V} на{на=PR} постановку{постановка=S} спектаклей{спектакль=S} на{на=PR} покупку{покупка=S} тканей{ткань=S} для{для=PR} костюмов{костюм=S} и{и=CONJ} декораций{декорация=S} на{на=PR} гонорары{гонорар=S} актёрам{актёр=S}
# Это{это=NI} было{быть=V} Наташка{наташка=S} два{два=NI} года{год=S} назад{назад=ADV} но{но=CONJ} всё{весь=A} по{по=PR} порядку{порядок=S}
# По{по=PR} этой{этот=A} же{же=ADV} причине{причина=S} полезны{полезный=A} занятия{занятие=S} бальными{бальный=A} танцами{танец=S} и{и=CONJ} художественной{художественный=A} гимнастикой{гимнастика=S}
# Циркуляция{циркуляция=S} этих{этот=A} вирусов{вирус=S} наблюдается{наблюдаться=V} как{как=ADV} правило{правило=S} в{в=PR} районах{район=S} с{с=PR} низким{низкий=A} охватом{охват=S} детей{ребёнок=S} прививками{прививка=S} ОПВ{ОПВ=S}
# Вопросы{вопрос=S} о{о=PR} природе{природа=S} и{и=CONJ} свойствах{свойство=S} математических{математический=A} объектов{объект=S} занимали{занимать=V} Витгенштейна{витгенштейн=S} на{на=PR} протяжении{протяжение=S} всей{весь=A} его{его=A} деятельности{деятельность=S}
# Впрочем{впрочем=CONJ} сам{сам=A} Аврелий{Аврелия=S} давно{давно=ADV} приучил{приучить=V} себя{себя=NI} к{к=PR} мысли{мысль=S} о{о=PR} неизбежной{неизбежный=A} кончине{кончина=S}
# Он{он=NI} получает{получать=V} дополнительные{дополнительный=A} баллы{балл=S} по{по=PR} шкале{шкала=S} военной{военный=A} пригодности{пригодность=S} и{и=CONJ} оказывается{оказываться=V} в{в=PR} элитных{элитный=A} десантных{десантный=A} войсках{войска=S}
# И{и=CONJ} почти{почесть=V} тут{тут=ADV} же{же=ADV} стал{стать=V} вновь{вновь=ADV} ощущаться{ощущаться=V} ток{ток=S} податливого{податливый=A} и{и=CONJ} призывного{призывной=A} тепла{тепло=S}
# На{на=PR} вчетверо{вчетверо=ADV} сложенном{сложить=V} листочке{листочек=S} отсутствует{отсутствовать=V} подпись{подпись=S} руководителя{руководитель=S} таинственного{таинственный=A} органа{орган=S} власти{власть=S} печать{печать=S} правда{правда=S} оттиснута{оттиснуть=V} подлинность{подлинность=S} её{её=A} удостоверена{удостоверить=V} каракулями{каракуль=S} машинистки{машинистка=S} той{тот=A} самой{самый=A} видимо{видимо=CONJ} старушенции{старушенция=S} что{что=CONJ} раздавала{раздавать=V} спешно{спешный=A} размноженные{размножить=V} сводки{сводка=S}
# Есть{есть=V} одна{один=A} вещь{вещь=S} в{в=PR} этом{это=NI} сотрудничестве{сотрудничество=S} которая{который=A} мне{я=NI} никогда{никогда=ADV} не{не=ADV} нравилась{нравиться=V} и{и=CONJ} которая{который=A} не{не=ADV} нравится{нравиться=V} и{и=CONJ} сейчас{сейчас=ADV}
# Как{как=ADV} и{и=CONJ} во{во=PR} многих{многий=A} других{другой=A} предприятиях{предприятие=S} с{с=PR} целью{цель=S} очистки{очистка=S} стоков{стоковый=A} здесь{здесь=ADV} использовали{использовать=V} промышленно{промышленный=A} изготовленные{изготовить=V} флораты{флораты=S} различной{различный=A} производительности{производительность=S}
# После{после=PR} определения{определение=S} в{в=PR} соответствии{соответствие=S} со{со=PR} значениями{значение=S} генов{ген=S} структуры{структура=S} сети{сеть=S} и{и=CONJ} распределения{распределение=S} трафика{трафик=S} проводится{проводиться=V} корректировка{корректировка=S} пропускной{пропускной=A} способности{способность=S} каналов{канал=S} и{и=CONJ} рассчитывается{рассчитываться=V} целевая{целевой=A} функция{функция=S}
# Наконец{наконец=CONJ} в{в=PR} декабре{декабрь=S} пятьдесят{пятьдесят=NI} шестого{шестой=A} года{год=S} пришла{прийти=V} бумага{бумага=S} из{из=PR} областного{областной=A} отдела{отдел=S} госбезопасности{госбезопасность=S} извещающая{извещать=V} о{о=PR} том{тот=A} что{что=CONJ} за{за=PR} отсутствием{отсутствие=S} состава{состав=S} преступления{преступление=S} дело{дело=S} гражданина{гражданин=S} Чумового{чумовой=A} производством{производство=S} прекращено{прекратить=V} и{и=CONJ} Ольга{Ольга=S} вылезла{вылезти=V} из{из=PR} шкафа{шкаф=S} таким{такой=A} образом{образ=S} воротившись{воротиться=V} в{в=PR} живую{живой=A} жизнь{жизнь=S}
# Исследователи{исследователь=S} же{же=ADV} ориентирующиеся{ориентироваться=V} на{на=PR} сатиру{сатир=S} нового{новый=A} времени{время=S} и{и=CONJ} особенно{особенно=ADV} на{на=PR} сатирический{сатирический=A} роман{роман=S} склонны{склонный=A} признавать{признавать=V} её{её=A} чисто{чистый=A} эпическим{эпический=A} явлением{явление=S}
# Описывается{описываться=V} сходство{сходство=S} юмористических{юмористический=A} выражений{выражение=S} и{и=CONJ} парадоксальных{парадоксальный=A} задач{задача=S} определяемое{определять=V} наличием{наличие=S} противоречия{противоречие=S} между{между=PR} кругом{кругом=ADV} связей{связь=S} в{в=PR} первоначальном{первоначальный=A} восприятии{восприятие=S} и{и=CONJ} осознанием{осознание=S} новых{новый=A} связей{связь=S} и{и=CONJ} отношений{отношение=S} в{в=PR} завершающем{завершать=V} суждении{суждение=S}
# Уже{уже=ADV} в{в=PR} воскресенье{воскресенье=S} в{в=PR} матче{матч=S} против{против=PR} чехов{чех=S} россияне{россиянин=S} вернулись{вернуться=V} к{к=PR} своей{свой=A} привычной{привычный=A} манере{манер=S} слишком{слишком=ADV} часто{часто=ADV} играя{играть=V} без{без=PR} оглядки{оглядка=S} на{на=PR} оборону{оборона=S} и{и=CONJ} в{в=PR} последние{последний=A} минуты{минута=S} едва{едва=ADV} не{не=ADV} упустили{упустить=V} добытый{добытый=V} перевес{перевес=S} в{в=PR} счёте{счёт=S}
# То{то=CONJ} скоропостижно{скоропостижный=A} заболевает{заболевать=V} один{один=A} адвокат{адвокат=S} потом{потом=ADV} другой{другой=A} внезапно{внезапно=ADV} уходит{уходить=V} в{в=PR} отпуск{отпуск=S} а{а=CONJ} третий{третий=A} исчезает{исчезать=V} неведомо{неведомый=A} куда{куда=S}
# Ограниченность{ограниченность=S} психозойской{психозойский=A} эры{эра=S} во{во=PR} времени{время=S} на{на=PR} различных{различный=A} планетах{планет=S} существенно{существенно=ADV} уменьшает{уменьшать=V} количество{количество=S} миров{мир=S} где{где=ADV} одновременно{одновременно=ADV} с{с=PR} нами{мы=NI} обитают{обитать=V} разумные{разумный=A} существа{существо=S}
# Руководители{руководитель=S} программ{программа=S} сообщили{сообщить=V} что{что=CONJ} количество{количество=S} заявок{заявка=S} как{как=ADV} правило{правило=S} раз{раз=S} в{в=PR} десять{десять=NI} превышает{превышать=V} количество{количество=S} предлагаемых{предлагать=V} мест{место=S}
# Иду{Ида=S} я{я=NI} по{по=PR} набережной{набережная=S} навстречу{навстречу=ADV} мне{я=NI} едва{едва=ADV} живой{живой=A} тащится{тащиться=V} знакомый{знакомый=A} врач{врач=S}
# Так{так=ADV} учёные{учёный=S} до{до=PR} сих{сей=A} пор{пора=S} не{не=ADV} знают{знать=V} какой{какой=A} рацион{рацион=S} питания{питание=S} лучше{хороший=A} всего{весь=A} подходит{подходить=V} для{для=PR} морских{морской=A} коньков{конёк=S}
# Разрушение{разрушение=S} или{или=CONJ} утилизация{утилизация=S} дореволюционных{дореволюционный=A} предметов{предмет=S} а{а=CONJ} также{также=ADV} продажа{продажа=S} особо{особо=ADV} ценных{ценный=A} из{из=PR} них{они=NI} за{за=PR} границу{граница=S} для{для=PR} получения{получение=S} валюты{валюта=S} становятся{становиться=V} не{не=ADV} просто{просто=ADV} прагматическим{прагматический=A} а{а=CONJ} идеологическим{идеологический=A} шагом{шаг=S}
# Использование{использование=S} вычислительной{вычислительный=A} техники{техник=S} позволяет{позволять=V} проводить{проводить=V} сложные{сложный=A} и{и=CONJ} многовариантные{многовариантный=A} исследования{исследование=S} и{и=CONJ} расчёты{расчёт=S} новых{новый=A} изделий{изделие=S} что{что=CONJ} приводит{приводить=V} к{к=PR} более{более=ADV} качественному{качественный=A} проектированию{проектирование=S}
# С{с=PR} особым{особый=A} трепетом{трепет=S} в{в=PR} РОСНО{росный=A} относятся{относиться=V} к{к=PR} гражданам{гражданин=S} выезжающим{выезжать=V} в{в=PR} Израиль{Израиль=S}
# Белые{белый=A} волосы{волос=S} на{на=PR} большой{большой=A} голове{голова=S} белое{белый=A} лицо{лицо=S} широкое{широкий=A} и{и=CONJ} тяжёлое{тяжёлый=A} книзу{книзу=ADV} совсем{совсем=ADV} белые{белый=A} брови{брови=S} над{над=PR} мелкими{мелкий=A} серыми{серый=A} глазами{глаз=S}
# Это{это=NI} потому{потому=ADV} что{что=CONJ} мне{я=NI} скучно{скучно=ADV} и{и=CONJ} мне{я=NI} хочется{хотеться=V} посмотреть{посмотреть=V} что{что=CONJ} дедушка{дедушка=S} будет{быть=V} делать{делать=V} если{если=CONJ} у{у=PR} него{он=NI} не{не=ADV} получится{получиться=V}
# Процесс{процесс=S} овладения{овладение=S} осуществляется{осуществляться=V} в{в=PR} ходе{ход=S} развития{развитие=S} реальных{реальный=A} отношений{отношение=S} субъекта{субъект=S} к{к=PR} миру{мир=S}
# И{и=CONJ} лишь{лишь=ADV} затем{затем=ADV} под{под=PR} звон{звон=S} колоколов{колокол=S} столичный{столичный=A} гость{гость=S} вступил{вступить=V} на{на=PR} территорию{территория=S} кремля{кремль=S} знаменитого{знаменитый=A} со{со=PR} времён{время=S} Ивана{Иван=S} Грозного{Грозный=S}
# Отсюда{отсюда=ADV} следует{следовать=V} что{что=CONJ} качество{качество=S} литературных{литературный=A} произведений{произведение=S} зависит{зависеть=V} от{от=PR} доли{доля=S} используемых{использовать=V} шаблонов{шаблон=S} в{в=PR} общем{общий=A} объёме{объём=S} текста{текст=S} числа{число=S} параметров{параметр=S} и{и=CONJ} разнообразия{разнообразие=S} авторских{авторский=A} вставок{вставка=S}
# Затем{затем=ADV} прикинул{прикинуть=V} размеры{размер=S} гранитного{гранитный=A} циклона{циклон=S} а{а=CONJ} также{также=ADV} угол{угол=S} наклона{наклон=S} горы{гора=S} и{и=CONJ} сделал{сделать=V} некоторые{некоторый=A} расчёты{расчёт=S} в{в=PR} записной{записной=A} книжке{книжка=S} которую{который=A} всегда{всегда=ADV} носил{носить=V} с{с=PR} собой{себя=NI}
# Скорости{скорость=S} газовых{газовый=A} облаков{облако=S} вблизи{вблизи=PR} ядра{ядро=S} формирующих{формировать=V} широкую{широкий=A} компоненту{компонент=S} профиля{профиль=S} линии{линия=S} излучения{излучение=S} оцениваются{оцениваться=V} по{по=PR} её{её=A} доплеровской{доплеровский=A} полуширине{полуширина=S}
# Для{для=PR} начала{начало=S} решено{решить=V} было{быть=V} создать{создать=V} заповедную{заповедный=A} зону{зона=S} общей{общий=A} площадью{площадь=S} тридцать{тридцать=NI} три{три=NI} гектара{гектар=S} где{где=ADV} полностью{полностью=ADV} запретили{запретить=V} ловить{ловить=V} рыбу{рыба=S}
# Они{они=NI} исчезнут{исчезнуть=V} естественным{естественный=A} образом{образ=S} если{если=CONJ} спрос{спрос=S} на{на=PR} их{их=A} услуги{услуга=S} упадёт{упасть=V}
# Злые{злой=A} языки{язык=S} утверждали{утверждать=V} что{что=CONJ} ему{он=NI} якобы{якобы=ADV} не{не=ADV} давала{давать=V} покоя{покой=S} статья{статья=S} Колесникова{колесников=S} о{о=PR} деревне{деревня=S} Терехово{Терехово=S} напечатанная{напечатать=V} в{в=PR} прошлом{прошлый=A} номере{номер=S}
# Другое{другой=A} дело{дело=S} в{в=PR} одной{один=A} стране{страна=S} она{она=NI} более{более=ADV} выражена{выразить=V} в{в=PR} другой{другой=A} менее{менее=ADV} выражена{выразить=V}
# Авторы{автор=S} данной{данный=A} статьи{статья=S} получили{получить=V} от{от=PR} Г{г=S} Бабаевой{бабаева=S} магнитофонную{магнитофонный=A} запись{запись=S} диалогов{диалог=S} Мэси{мэси=S} сделанную{сделать=V} на{на=PR} бытовом{бытовой=A} кассетном{кассетный=A} магнитофоне{магнитофон=S}
# Да{да=CONJ} эти{этот=A} операции{операция=S} платные{платный=A} и{и=CONJ} нужны{нужный=A} новые{новый=A} врачи{врач=S} говорят{говорить=V} как{как=ADV} минимум{минимум=ADV} ещё{ещё=ADV} две{два=NI}
# США{США=S} больше{большой=A} занимают{занимать=V} очаги{очаг=S} конфликтов{конфликт=S} и{и=CONJ} будущие{будущий=A} границы{граница=S} регионов{регион=S} входящих{входить=V} в{в=PR} Югославию{Югославия=S}
# Вся{весь=A} высшая{высший=A} нервная{нервный=A} деятельность{деятельность=S} связана{связать=V} в{в=PR} основном{основное=S} с{с=PR} корой{кора=S} головного{головной=A} мозга{мозг=S}
# Без{без=PR} правильного{правильный=A} определения{определение=S} потребностей{потребность=S} целевой{целевой=A} аудитории{аудитория=S} будут{быть=V} бессмысленны{бессмысленный=A} вложения{вложение=S} в{в=PR} каналы{канал=S} сбыта{сбыт=S}
# С{с=PR} тех{тот=A} пор{пора=S} наши{наш=A} сведения{сведение=S} о{о=PR} Вселенной{вселенная=S} неизмеримо{неизмеримый=A} выросли{вырасти=V} исследователи{исследователь=S} широко{широко=ADV} используют{использовать=V} выдающиеся{выдающийся=A} достижения{достижение=S} теоретической{теоретический=A} физики{физик=S}
# Немецкие{немецкий=A} учёные{учёный=S} из{из=PR} университета{университет=S} города{город=S} Гисена{Гисена=S} поместили{поместить=V} двести{двести=NI} испытуемых{испытуемый=S} добровольцев{доброволец=S} в{в=PR} специальную{специальный=A} камеру{камера=S} изолированную{изолировать=V} от{от=PR} магнитного{магнитный=A} поля{поле=S} Земли{земля=S} своего{свой=A} рода{род=S} ловушку{ловушка=S} напоминающую{напоминать=V} токамак{токамак=S} где{где=ADV} удерживается{удерживаться=V} плазма{плазма=S}
# Но{но=CONJ} я{я=NI} свыкся{свыкнуться=V} с{с=PR} ним{он=NI} ибо{ибо=CONJ} в{в=PR} нём{он=NI} не{не=ADV} было{быть=V} ничего{ничего=ADV} злого{злой=A} в{в=PR} нём{он=NI} не{не=ADV} было{быть=V} лжи{ложь=S}
# Начиная{начинать=V} с{с=PR} древнегреческих{древнегреческий=A} произведений{произведение=S} я{я=NI} веду{веду=V} особую{особый=A} линию{линия=S} диалогического{диалогический=A} романа{роман=S} до{до=PR} Достоевского{достоевский=S}
# Книголюб{книголюб=S} нежно{нежный=A} подхватил{подхватить=V} писателя{писатель=S} под{под=PR} руку{рука=S} и{и=CONJ} тот{тот=A} бедром{бедро=S} почувствовал{почувствовать=V} его{его=A} карман{карман=S}
# Ну{ну=ADV} может{мочь=V} и{и=CONJ} читали{читать=V} Пушкина{Пушкин=S} а{а=CONJ} Вийона{Вийона=S} и{и=CONJ} не{не=ADV} читали{читать=V}
# Очень{очень=ADV} интересные{интересный=A} композиции{композиция=S} можно{можно=NI} составить{составить=V} из{из=PR} хост{хост=S} с{с=PR} разной{разный=A} окраской{окраска=S} листьев{лист=S}
# Он{он=NI} призван{призвать=V} иллюстрировать{иллюстрировать=V} собственные{собственный=A} идеи{идея=S} автора{автор=S} которые{который=A} она{она=NI} развивает{развивать=V} в{в=PR} исследовательской{исследовательский=A} части{часть=S} своего{свой=A} труда{труд=S}
# Поэтому{поэтому=ADV} дифференцированный{дифференцировать=V} подход{подход=S} и{и=CONJ} трезвое{трезвый=A} отношение{отношение=S} к{к=PR} ситуации{ситуация=S} со{со=PR} стороны{сторона=S} мамы{мама=S} помогут{помочь=V} избежать{избежать=V} многих{многий=A} неприятностей{неприятность=S}
# Шкап{шкап=S} тёти{тётя=S} Мари{Мари=S} остался{остаться=V} в{в=PR} брошенной{бросить=V} квартире{квартира=S} с{с=PR} забитыми{забить=V} окнами{окно=S}
# В{в=PR} Комнате{комната=S} боевой{боевой=A} славы{слава=S} Валентин{Валентин=S} Петрович{Пётр=S} собрал{собрать=V} музей{музей=S} водолазного{водолазный=A} дела{дело=S}
# Ныне{ныне=ADV} ясно{ясно=ADV} что{что=CONJ} ещё{ещё=ADV} недавно{недавно=ADV} распространённое{распространить=V} в{в=PR} литературе{литература=S} мнение{мнение=S} согласно{согласно=PR} которому{который=A} ареал{ареал=S} первоначального{первоначальный=A} проживания{проживание=S} славян{славянин=S} должен{должен=A} выделяться{выделяться=V} наибольшей{наибольший=A} сосредоточенностью{сосредоточенность=S} славянской{славянский=A} гидронимики{гидронимика=S} или{или=CONJ} чисто{чистый=A} славянскими{славянский=A} водными{водный=A} названиями{название=S} является{являться=V} ошибочным{ошибочный=A}
# Это{это=NI} нашло{найти=V} отражение{отражение=S} в{в=PR} теоретическом{теоретический=A} равноправии{равноправие=S} уравнений{уравнение=S} с{с=PR} так{так=ADV} называемыми{называть=V} запаздывающими{запаздывать=V} и{и=CONJ} опережающими{опережать=V} потенциалами{потенциал=S}
# К{к=PR} Новому{новый=A} году{год=S} от{от=PR} школы{школа=S} останется{остаться=V} лишь{лишь=ADV} пустая{пустой=A} коробка{коробка=S} с{с=PR} чёрными{чёрный=A} проёмами{проём=S}
# Вот{вот=ADV} попробуй{попробовать=V} сыграй{сыграть=V} такую{такой=A} на{на=PR} этюдах{этюд=S} ведь{ведь=ADV} ни{ни=ADV} за{за=PR} что{что=CONJ} не{не=ADV} сумеешь{суметь=V}
# Клянусь{клясться=V} брюхом{брюхо=S} акулы{акула=S} это{это=NI} будет{быть=V} самое{самый=A} весёлое{весёлый=A} представление{представление=S} в{в=PR} мире{мир=S}
# Установлено{установить=V} что{что=CONJ} изученные{изучить=V} фосфорорганические{фосфорорганический=A} кислоты{кислота=S} и{и=CONJ} их{их=A} производные{производная=S} разлагаются{разлагаться=V} при{при=PR} нагреве{нагрев=S} по{по=PR} другому{другой=A} механизму{механизм=S} в{в=PR} сравнении{сравнение=S} с{с=PR} неразветвленными{неразветвленный=A} аналогами{аналог=S}
# На{на=PR} Западе{запад=S} знают{знать=V} показатели{показатель=S} российской{российский=A} экономики{экономика=S} и{и=CONJ} умеют{уметь=V} складывать{складывать=V} цифры{цифра=S} причём{причём=CONJ} в{в=PR} свою{свой=A} пользу{польза=S}
# Но{но=CONJ} ведь{ведь=ADV} это{это=NI} же{же=ADV} безграмотный{безграмотный=A} подход{подход=S} с{с=PR} точки{точка=S} зрения{зрение=S} управления{управление=S}
# Тётушка{тётушка=S} мамалыжной{мамалыжный=A} лопатой{лопата=S} накладывает{накладывать=V} каждому{каждый=A} свою{свой=A} порцию{порция=S} прямо{прямой=A} на{на=PR} тщательно{тщательно=ADV} выскобленную{выскоблить=V} розовую{розовый=A} доску{доска=S} стола{стол=S}
# Но{но=CONJ} для{для=PR} этого{это=NI} ему{он=NI} нужно{нужный=A} обнажить{обнажить=V} душу{душ=S} и{и=CONJ} тело{тело=S} а{а=CONJ} в{в=PR} холодной{холодный=A} действительности{действительность=S} так{так=ADV} не{не=ADV} прожить{прожить=V}
# Мне{я=NI} кажется{кажется=CONJ} в{в=PR} любом{любой=A} деле{дело=S} первоначальный{первоначальный=A} страх{страх=S} силен{силен=S} тем{тот=A} что{что=CONJ} предстаёт{представать=V} в{в=PR} наших{наш=A} ощущениях{ощущение=S} как{как=ADV} шаг{шаг=S} в{в=PR} зияющую{зиять=V} пустоту{пустота=S} в{в=PR} бесконечный{бесконечный=A} ужас{ужас=S}
# Я{я=NI} впервые{впервые=ADV} заметила{заметить=V} что{что=CONJ} великие{великий=A} композиторы{композитор=S} ужасно{ужасно=ADV} затягивали{затягивать=V} свои{свой=A} музыкальные{музыкальный=A} произведения{произведение=S}
# Известный{известный=A} американский{американский=A} радиоастроном{радиоастроный=A} Ф{ф=S} Дрэйк{Дрэйк=S} разработал{разработать=V} проект{проект=S} аппаратуры{аппаратура=S} способной{способный=A} решить{решить=V} поставленную{поставить=V} задачу{задача=S}
# Конструктивистская{конструктивистский=A} перспектива{перспектива=S} была{быть=V} развита{развить=V} институциональной{институциональный=A} и{и=CONJ} неоинституциональной{неоинституциональный=A} экономической{экономический=A} теорией{теория=S} представители{представитель=S} которой{который=A} делали{делать=V} основной{основной=A} акцент{акцент=S} на{на=PR} изучении{изучение=S} того{тот=A} как{как=ADV} социальные{социальный=A} факторы{фактор=S} формируют{формировать=V} ценность{ценность=S} товаров{товар=S}
# Но{но=CONJ} тронет{тронуть=V} тихой{тихий=A} воздушной{воздушный=A} волной{волна=S} и{и=CONJ} откатит{откатить=V} и{и=CONJ} уж{уж=S} с{с=PR} другого{другой=A} бока{бок=S} ответный{ответный=A} лёгкий{лёгкий=A} порыв{порыв=S}
# И{и=CONJ} вот{вот=ADV} эпохальный{эпохальный=A} проезд{проезд=S} по{по=PR} омским{омский=A} улицам{улица=S} и{и=CONJ} дворам{двор=S} губернатора{губернатор=S} Полежаева{полежаев=S}
# Милиционер{милиционер=S} только{только=ADV} развёл{развести=V} руками{рука=S} когда{когда=CONJ} я{я=NI} высказал{высказать=V} сомнение{сомнение=S} в{в=PR} том{тот=A} что{что=CONJ} профессионально{профессионально=ADV} сделанную{сделать=V} шпионскую{шпионский=A} аппаратуру{аппаратура=S} удастся{удался=V} обнаружить{обнаружить=V} путём{путём=PR} сверки{сверка=S} номеров{номер=S}
# Прежде{прежде=PR} чем{чем=CONJ} семейное{семейный=A} предприятие{предприятие=S} стало{стать=V} промышленным{промышленный=A} пивовары{пивовар=S} ездили{ездить=V} в{в=PR} Баварию{Бавария=S} осваивать{осваивать=V} тамошние{тамошний=A} секреты{секрет=S} рецептуры{рецептура=S} и{и=CONJ} технологии{технология=S}
# Колюней{колюня=S} спал{спасть=V} на{на=PR} Мишке{мишка=S} и{и=CONJ} видно{видный=A} ему{он=NI} снились{сниться=V} хорошие{хороший=A} сны{сон=S}
# Можно{можно=NI} предположить{предположить=V} что{что=CONJ} эксплуатируя{эксплуатировать=V} именно{именно=ADV} чувство{чувство=S} страха{страх=S} легко{легко=ADV} возбудимое{возбудимый=A} в{в=PR} средневековом{средневековый=A} человеке{человек=S} церковь{церковь=S} всего{весь=A} успешнее{успешный=A} могла{мочь=V} внушить{внушить=V} пастве{паства=S} мысль{мысль=S} о{о=PR} необходимости{необходимость=S} праведного{праведный=A} образа{образ=S} мыслей{мысль=S} и{и=CONJ} соответствующего{соответствовать=V} поведения{поведение=S}
# И{и=CONJ} это{это=NI} абсолютно{абсолютно=ADV} невозможно{невозможно=ADV} если{если=CONJ} беременность{беременность=S} наступает{наступать=V} как{как=ADV} несчастный{несчастный=A} случай{случай=S}
# И{и=CONJ} это{это=NI} отнюдь{отнюдь=ADV} не{не=ADV} означает{означать=V} что{что=CONJ} почта{почта=S} заменила{заменить=V} банки{банк=S} просто{просто=ADV} они{они=NI} научились{научиться=V} хорошо{хороший=A} взаимно{взаимный=A} дополнять{дополнять=V} друг{друг=S} друга{друг=S} оставаясь{оставаться=V} юридически{юридически=ADV} независимыми{независимый=A}
# Молодой{молодой=A} и{и=CONJ} красивой{красивый=A} принцессой{принцесса=S} прабабке{прабабка=S} остаться{остаться=V} не{не=ADV} удалось{удался=V} и{и=CONJ} одной{один=A} из{из=PR} вёсен{весна=S} она{она=NI} умерла{умер=V} от{от=PR} воспаления{воспаление=S} лёгких{лёгкий=A}
# Такое{такой=A} порабощение{порабощение=S} европейцев{европеец=S} позднее{поздний=A} не{не=ADV} выдержало{выдержать=V} конкуренции{конкуренция=S} с{с=PR} ввозом{ввоз=S} жителей{житель=S} Африки{Африка=S} те{тот=A} становились{становиться=V} рабами{раб=S} пожизненно{пожизненный=A} что{что=CONJ} подкреплялось{подкрепляться=V} пропагандой{пропаганда=S} расовых{расовый=A} отличий{отличие=S}
# За{за=PR} одиннадцать{одиннадцать=NI} послевоенных{послевоенный=A} лет{лета=S} решила{решить=V} и{и=CONJ} Матрёна{матрёна=S} сама{сам=A} что{что=CONJ} он{он=NI} не{не=ADV} жив{живой=A}
# И{и=CONJ} власть{власть=S} естественно{естественный=A} этому{этот=A} сопротивляется{сопротивляться=V} и{и=CONJ} есть{есть=V} раскол{раскол=S} который{который=A} сейчас{сейчас=ADV} будет{быть=V} преодолён{преодолён=V} безусловно{безусловный=A}
# Это{это=NI} даст{дал=V} возможность{возможность=S} розничным{розничный=A} торговым{торговый=A} предприятиям{предприятие=S} правильнее{правильный=A} планировать{планировать=V} ассортимент{ассортимент=S} и{и=CONJ} размеры{размер=S} закупок{закупка=S} и{и=CONJ} товарных{товарный=A} запасов{запас=S}
# Не{не=ADV} оставляйте{оставлять=V} ребенка{ребёнок=S} наедине{наедине=ADV} с{с=PR} его{его=A} страхами{страх=S} и{и=CONJ} попытайтесь{попытаться=V} совместными{совместный=A} усилиями{усилие=S} сделать{сделать=V} его{его=A} учёбу{учёба=S} в{в=PR} школе{школа=S} приятной{приятный=A} и{и=CONJ} плодотворной{плодотворный=A}
# Очередь{очередь=S} эта{этот=A} была{быть=V} в{в=PR} полтора{полтора=NI} месяца{месяц=S} раз{раз=S} но{но=CONJ} вгоняла{вгонять=V} Матрену{Матрену=S} в{в=PR} большой{большой=A} расход{расход=S}
# В{в=PR} этих{этот=A} делах{дело=S} Коля{Коля=S} был{быть=V} бит{бить=V} и{и=CONJ} натаскан{натаскать=V} знал{знать=V} кого{кто=NI} надо{надо=NI} угощать{угощать=V} в{в=PR} расчёте{расчёт=S} на{на=PR} ответное{ответный=A} угощение{угощение=S}
# Типично{типичный=A} славянские{славянский=A} названия{название=S} вод{вод=S} также{также=ADV} не{не=ADV} свидетельствуют{свидетельствовать=V} о{о=PR} древности{древность=S} заселения{заселение=S} славянами{славянин=S} конкретной{конкретный=A} упоминаемой{упоминать=V} местности{местность=S} это{это=NI} могут{мочь=V} быть{быть=V} регионы{регион=S} позднего{поздний=A} освоения{освоение=S} ими{они=NI}
# ...
# Левицкий{левицкий=S} конечно{конечно=CONJ} с{с=PR} браком{брак=S} отбил{отбить=V} дальний{дальний=A} удар{удар=S} Гашека{гашек=S} но{но=CONJ} защитники{защитник=S} как{как=ADV} вкопанные{вкопать=V} наблюдали{наблюдать=V} за{за=PR} тем{тот=A} как{как=ADV} чужой{чужой=A} игрок{игрок=S} набегает{набегать=V} и{и=CONJ} сравнивает{сравнивать=V} счёт{счёт=S}
# По{по=PR} наблюдениям{наблюдение=S} зоологов{зоолог=S} обезьяны{обезьяна=S} тоже{тоже=ADV} порой{порой=ADV} ищут{искать=V} перезревшие{перезреть=V} фрукты{фрукт=S} в{в=PR} которых{который=A} уже{уже=ADV} начинается{начинаться=V} процесс{процесс=S} брожения{брожение=S} и{и=CONJ} с{с=PR} наслаждением{наслаждение=S} поглощают{поглощать=V} их{их=A}
# Не{не=ADV} исключено{исключить=V} что{что=CONJ} показанная{показать=V} его{его=A} командой{команда=S} в{в=PR} Швеции{Швеция=S} разумная{разумный=A} игра{игра=S} есть{есть=V} временное{временной=A} явление{явление=S} требовавшееся{требоваться=V} руководству{руководство=S} сборной{сборная=S} чтобы{чтобы=CONJ} уверенно{уверенный=A} готовить{готовить=V} её{её=A} к{к=PR} поездке{поездка=S} на{на=PR} мировое{мировой=A} первенство{первенство=S} а{а=CONJ} там{там=ADV} опять{опять=ADV} предаться{предаться=V} бесшабашности{бесшабашность=S} и{и=CONJ} торжеству{торжество=S} эмоций{эмоция=S} забыв{забыть=V} про{про=PR} столь{столь=ADV} нелюбимое{нелюбимый=A} Плющевым{плющевой=A} дело{дело=S} как{как=ADV} игра{игра=S} на{на=PR} результат{результат=S}
# Это{это=NI} наколенники{наколенник=S} налокотники{налокотник=S} одеяла{одеяло=S} покрывала{покрывало=S} наматрасники{наматрасник=S} подушки{подушка=S} чехлы{чехол=S} для{для=PR} сидений{сидение=S} автомобилей{автомобиль=S} тапочки{тапочки=S} для{для=PR} детей{ребёнок=S} и{и=CONJ} взрослых{взрослый=S} конверты{конверт=S} для{для=PR} грудных{грудной=A} младенцев{младенец=S} и{и=CONJ} ковры{ковёр=S}
# Он{он=NI} приблизил{приблизить=V} свой{свой=A} единственный{единственный=A} глаз{глаз=S} к{к=PR} моему{мой=A} лицу{лицо=S} и{и=CONJ} я{я=NI} увидел{увидеть=V} в{в=PR} чёрном{чёрный=A} зрачке{зрачок=S} столько{столько=CONJ} ярости{ярость=S} и{и=CONJ} жестокости{жестокость=S} что{что=CONJ} почувствовал{почувствовать=V} как{как=ADV} весь{весь=A} холодею{холодеть=V} от{от=PR} ужаса{ужас=S}
# Да{да=CONJ} что{что=CONJ} об{об=PR} этом{это=NI} толковать{толковать=V} в{в=PR} пьяный{пьяный=A} кураж{кураж=S} впавшему{впасть=V} человеку{человек=S}
# Я{я=NI} увидел{увидеть=V} как{как=ADV} она{она=NI} согнала{согнать=V} с{с=PR} лица{лицо=S} улыбку{улыбка=S} и{и=CONJ} наверно{наверно=CONJ} для{для=PR} того{тот=A} чтобы{чтобы=CONJ} не{не=ADV} рассмеяться{рассмеяться=V} прикусила{прикусить=V} нижнюю{нижний=A} губу{губа=S}
# И{и=CONJ} теперь{теперь=ADV} она{она=NI} приехала{приехать=V} на{на=PR} каникулы{каникулы=S} а{а=CONJ} дед{дед=S} вот{вот=ADV} едет{еду=V} навестить{навестить=V}
# Не{не=ADV} случайно{случайный=A} в{в=PR} начале{начало=S} встречи{встреча=S} он{он=NI} как{как=ADV} бы{бы=ADV} невзначай{невзначай=ADV} проронил{проронить=V} что{что=CONJ} три{три=NI} года{год=S} не{не=ADV} общался{общаться=V} один{один=A} на{на=PR} один{один=A} с{с=PR} журналистами{журналист=S} в{в=PR} рамках{рамка=S} брифинга{брифинг=S} а{а=CONJ} вот{вот=ADV} сейчас{сейчас=ADV} готов{готовый=A} ответить{ответить=V} на{на=PR} все{весь=A} вопросы{вопрос=S}
# Видимо{видимо=CONJ} её{её=A} детская{детский=A} душа{душ=S} безотчетно{безотчетно=S} разделяла{разделять=V} несообразные{несообразный=A} свойства{свойство=S} жизни{жизнь=S} и{и=CONJ} уродливость{уродливость=S} одной{один=A} не{не=ADV} закрывала{закрывать=V} красоты{красота=S} другой{другой=A} и{и=CONJ} не{не=ADV} лишала{лишать=V} счастья{счастье=S} любоваться{любоваться=V} ею{она=NI}
# На{на=PR} минувшем{минувший=A} юниорском{юниорский=A} чемпионате{чемпионат=S} мира{мир=S} ни{ни=ADV} одной{один=A} россиянке{россиянка=S} не{не=ADV} удалось{удался=V} пробиться{пробиться=V} в{в=PR} десятку{десятка=S} сильнейших{сильнейший=A}
# Я{я=NI} отлично{отлично=ADV} помню{помнить=V} как{как=ADV} начал{начать=V} понимать{понимать=V} что{что=CONJ} я{я=NI} тоже{тоже=ADV} имею{иметь=V} устройство{устройство=S}
# Одолев{одолеть=V} его{его=A} мы{мы=NI} не{не=ADV} опасность{опасность=S} устраняем{устранять=V} а{а=CONJ} находим{находить=V} меру{мера=S} тому{тот=A} что{что=CONJ} мы{мы=NI} считали{считать=V} бесконечностью{бесконечность=S}
# Нечто{нечто=NI} подобное{подобный=A} нельзя{нельзя=NI} теоретически{теоретически=ADV} исключать{исключать=V} и{и=CONJ} в{в=PR} будущем{будущее=S} именно{именно=ADV} в{в=PR} связи{связь=S} с{с=PR} нелинейностью{нелинейность=S} развития{развитие=S} сложных{сложный=A} систем{система=S}
# На{на=PR} фотографии{фотография=S} сохранившейся{сохраниться=V} с{с=PR} тех{тот=A} времён{время=S} мы{мы=NI} сняты{снять=V} на{на=PR} фоне{фон=S} полуразвалившегося{полуразвалившегося=S} Шамординского{Шамординского=S} собора{собор=S}
# Если{если=CONJ} это{это=NI} так{так=ADV} то{то=CONJ} когда{когда=CONJ} это{это=NI} было{быть=V} в{в=PR} какие{какой=A} времена{время=S}
# Было{быть=V} время{время=S} когда{когда=CONJ} мы{мы=NI} жаловались{жаловаться=V} на{на=PR} отсутствие{отсутствие=S} дебютов{дебют=S} потом{потом=ADV} на{на=PR} отсутствие{отсутствие=S} качественных{качественный=A} дебютов{дебют=S}
# Черепные{черепной=A} нервы{нерв=S} в{в=PR} целом{целое=S} похожи{похожий=A} на{на=PR} спинномозговые{спинномозговой=A} но{но=CONJ} имеют{иметь=V} некоторые{некоторый=A} особенности{особенность=S} связанные{связать=V} с{с=PR} условиями{условие=S} развития{развитие=S}
# Он{он=NI} то{то=CONJ} замирал{замирать=V} качаясь{качаться=V} на{на=PR} пятках{пятка=S} то{то=CONJ} припадая{припадать=V} к{к=PR} земле{земля=S} мчался{мчаться=V} автомобилю{автомобиль=S} наперерез{наперерез=ADV}
# Подполковник{подполковник=S} Гуров{гуров=S} однако{однако=CONJ} не{не=ADV} в{в=PR} части{часть=S} а{а=CONJ} у{у=PR} себя{себя=NI} дома{дом=S}
# И{и=CONJ} тут{тут=ADV} он{он=NI} заметил{заметить=V} что{что=CONJ} у{у=PR} Кати{катить=V} немолодое{немолодой=A} морщинистое{морщинистый=A} личико{личико=S} и{и=CONJ} ручки{ручка=S} сложенные{сложить=V} лодочкой{лодочка=S} под{под=PR} подбородком{подбородок=S} тоже{тоже=ADV} уже{уже=ADV} немолодые{немолодой=A}
# Вопрос{вопрос=S} был{быть=V} таким{такой=A} неожиданным{неожиданный=A} что{что=CONJ} Юрка{юркий=A} не{не=ADV} сразу{сразу=ADV} сообразил{сообразить=V} что{что=CONJ} ответить{ответить=V}
# Стайка{стайка=S} девиц{девица=S} по{по=PR} всей{весь=A} видимости{видимость=S} подруг{подруга=S} невесты{невеста=S} показывает{показывать=V} длинные{длинный=A} ноги{нога=S} и{и=CONJ} дисциплинированные{дисциплинировать=V} ещё{ещё=ADV} не{не=ADV} вздыбившиеся{вздыбиться=V} груди{грудь=S} и{и=CONJ} держатся{держаться=V} особняком{особняк=S} с{с=PR} прелестным{прелестный=A} любопытством{любопытство=S} шушукаясь{шушукаться=V} и{и=CONJ} наблюдая{наблюдать=V} за{за=PR} передвижением{передвижение=S} фигур{фигура=S}
# Сейчас{сейчас=ADV} президент{президент=S} Путин{путина=S} пытается{пытаться=V} добиться{добиться=V} большей{больший=A} координации{координация=S} между{между=PR} уровнями{уровень=S} власти{власть=S}
# Бабочки{бабочка=S} пчёлы{пчела=S} и{и=CONJ} другие{другой=A} летающие{летать=V} насекомые{насекомое=S} чтобы{чтобы=CONJ} разогреться{разогреться=V} усиленно{усиленно=ADV} двигаются{двигаться=V}
# С{с=PR} другой{другой=A} стороны{сторона=S} человек{человек=S} у{у=PR} которого{который=A} Володя{Володя=S} подрабатывал{подрабатывать=V} в{в=PR} магазине{магазин=S} предложил{предложить=V} ему{он=NI} стать{стать=V} бухгалтером{бухгалтер=S} в{в=PR} казино{казино=S}
# Они{они=NI} тоньше{тонкий=A} латексных{латексный=A} и{и=CONJ} не{не=ADV} боятся{бояться=V} смазки{смазка=S} на{на=PR} масляной{масляный=A} основе{основа=S}
# А{а=CONJ} вдобавок{вдобавок=ADV} мой{мой=A} отец{отец=S} имеющий{иметь=V} золотые{золотой=A} руки{рука=S} и{и=CONJ} знающий{знать=V} древние{древний=A} языки{язык=S} непонятно{непонятно=ADV} зачем{зачем=ADV} склеил{склеить=V} по{по=PR} кусочкам{кусочек=S} её{её=A} молельные{молельный=A} книжечки{книжечка=S}
# То{то=CONJ} же{же=ADV} относится{относиться=V} и{и=CONJ} к{к=PR} случаю{случай=S} отсутствия{отсутствие=S} заранее{заранее=ADV} заданного{задать=V} списка{список=S} персонажей{персонаж=S}
# Они{они=NI} молча{молчать=V} пошли{пойти=V} на{на=PR} запад{запад=S} с{с=PR} разбега{разбег=S} перепрыгивая{перепрыгивать=V} пустоты{пустота=S} над{над=PR} резиновыми{резиновый=A} сочленениями{сочленение=S} переходов{переход=S}
# В{в=PR} Генеральной{генеральный=A} прокуратуре{прокуратура=S} России{Россия=S} подтвердили{подтвердить=V} факт{факт=S} задержания{задержание=S} третьего{третий=A} фигуранта{фигурант=S} по{по=PR} делу{дело=S} об{об=PR} убийстве{убийство=S} депутата{депутат=S} Госдумы{Госдума=S} Сергея{Сергей=S} Юшенкова{юшенков=S}
# Он{он=NI} стоял{стоять=V} посреди{посреди=PR} нескончаемой{нескончаемый=A} равнины{равнина=S} ранним{ранний=A} утром{утром=ADV} и{и=CONJ} смотрел{смотреть=V} вдаль{вдаль=ADV} поверх{поверх=PR} наших{наш=A} голов{гол=S}
# Зимой{зима=S} мы{мы=NI} наивно{наивный=A} считали{считать=V} что{что=CONJ} снег{снег=S} всё{весь=A} скроет{скрыть=V} метель{метель=S} занесёт{занести=V}
# Он{он=NI} уже{уже=ADV} привык{привыкнуть=V} своими{свой=A} ногами{нога=S} ходить{ходить=V} в{в=PR} школу{школа=S} вместе{вместе=ADV} с{с=PR} друзьями{друг=S} гулять{гулять=V} с{с=PR} собакой{собака=S} жить{жить=V} обычной{обычный=A} жизнью{жизнь=S} всегда{всегда=ADV} помня{помнить=V} что{что=CONJ} всё{весь=A} это{это=NI} благодаря{благодаря=PR} добрым{добрый=A} людям{человек=S}
# В{в=PR} результате{результат=S} сочетания{сочетание=S} противоположных{противоположный=A} по{по=PR} смыслу{смысл=S} определений{определение=S} понятий{понятие=S} возникает{возникать=V} новое{новый=A} смысловое{смысловой=A} качество{качество=S}
# Русская{русский=A} интеллигенция{интеллигенция=S} вступила{вступить=V} в{в=PR} эпоху{эпоха=S} Красного{красный=A} Октября{октябрь=S} закалённая{закалить=V} в{в=PR} своём{свой=A} сопротивлении{сопротивление=S} царскому{царский=A} правительству{правительство=S}
# И{и=CONJ} я{я=NI} думал{думать=V} что{что=CONJ} она{она=NI} ранена{ранить=V} или{или=CONJ} убита{убить=V} что{что=CONJ} ей{она=NI} больно{больно=ADV} что{что=CONJ} она{она=NI} испугалась{испугаться=V}
# Когда{когда=CONJ} зоркий{зоркий=A} старлей{старлий=A} изгнал{изгнать=V} его{его=A} из{из=PR} числа{число=S} тех{тот=A} кто{кто=NI} пошёл{пойти=V} на{на=PR} разоружение{разоружение=S} Вовка{Вовка=S} от{от=PR} нечего{нечего=NI} делать{делать=V} вернулся{вернуться=V} в{в=PR} домишко{домишко=S} где{где=ADV} жила{жить=V} молодая{молодой=A} женщина{женщина=S}
# А{а=CONJ} управлять{управлять=V} всеми{весь=A} этими{этот=A} чудесами{чудеса=S} можно{можно=NI} одним{один=A} нажатием{нажатие=S} на{на=PR} сенсорное{сенсорный=A} стекло{стекло=S} закрывающее{закрывать=V} циферблат{циферблат=S}
# При{при=PR} этом{это=NI} исследованию{исследование=S} сути{суть=S} потребительских{потребительский=A} запасов{запас=S} по{по=PR} мнению{мнение=S} автора{автор=S} уделяется{уделяться=V} недостаточно{недостаточно=ADV} внимания{внимание=S}
# Лишь{лишь=ADV} мы{мы=NI} одни{один=A} бодрствовали{бодрствовать=V} в{в=PR} этом{это=NI} мире{мир=S} непреклонно{непреклонный=A} приближаясь{приближаться=V} к{к=PR} своей{свой=A} великой{великий=A} цели{цель=S}
# В{в=PR} июле{июль=S} Кирилл{Кирилл=S} уехал{уехать=V} со{со=PR} студенческим{студенческий=A} отрядом{отряд=S} в{в=PR} Новгород{Новгород=S} а{а=CONJ} мы{мы=NI} с{с=PR} Ритой{Рита=S} в{в=PR} конце{конец=S} июля{июль=S} взяли{взять=V} путёвки{путёвка=S} на{на=PR} Рижское{рижский=A} взморье{взморье=S} поехали{поехать=V} немного{немного=ADV} раньше{раньше=A} пожили{пожить=V} в{в=PR} гостинице{гостиница=S} а{а=CONJ} с{с=PR} августа{август=S} поселились{поселиться=V} в{в=PR} доме{дом=S} отдыха{отдых=S}
# Особенно{особенно=ADV} тяжелы{тяжёлый=A} были{быть=V} последние{последний=A} дни{день=S} перед{перед=PR} отправлением{отправление=S} к{к=PR} мифическому{мифический=A} калужскому{калужский=A} скорняку{скорняк=S}
# И{и=CONJ} насладится{насладиться=V} ею{она=NI} и{и=CONJ} надоест{надоел=V} римлянам{римлянин=S} своими{свой=A} причудами{причуда=S} или{или=CONJ} тиранией{тирания=S} и{и=CONJ} погибнет{погибнуть=V} через{через=PR} считанные{считать=V} годы{год=S} как{как=ADV} погибли{погибнуть=V} зазнавшийся{зазнаться=V} Нерон{нерон=S} и{и=CONJ} обезумевший{обезуметь=V} Калигула{Калигула=S}
# Если{если=CONJ} теперь{теперь=ADV} Судьбе{судьба=S} угоден{угодный=A} германец{германец=S} или{или=CONJ} эфиоп{эфиоп=S} финикиец{финикиец=S} или{или=CONJ} иудей{иудей=S} либо{либо=CONJ} вообще{вообще=ADV} христианин{христианин=S} без{без=PR} роду{род=S} и{и=CONJ} племени{племя=S} пусть{пусть=ADV} так{так=ADV} и{и=CONJ} будет{быть=V}
# В{в=PR} рамках{рамка=S} реформы{реформа=S} системы{система=S} социального{социальный=A} страхования{страхование=S} Минтруд{минтруд=S} России{Россия=S} предлагает{предлагать=V} изменить{изменить=V} схему{схема=S} выплаты{выплата=S} компенсаций{компенсация=S} сотрудникам{сотрудник=S} по{по=PR} больничным{больничный=A} листам{лист=S}
# Часто{часто=ADV} воды{вод=S} не{не=ADV} хватало{хватать=V} на{на=PR} всех{весь=A} и{и=CONJ} с{с=PR} полными{полный=A} вёдрами{ведро=S} шли{идти=V} только{только=ADV} счастливые{счастливый=A} первые{первый=A}
# Безусловно{безусловный=A} следует{следовать=V} отметить{отметить=V} что{что=CONJ} большинство{большинство=S} современных{современный=A} пакетов{пакет=S} имитационного{имитационный=A} моделирования{моделирование=S} позволяет{позволять=V} пользователю{пользователь=S} включать{включать=V} в{в=PR} модель{модель=S} собственные{собственный=A} компоненты{компонент=S} реализованные{реализовать=V} на{на=PR} любом{любой=A} языке{язык=S} программирования{программирование=S} и{и=CONJ} оптимизированные{оптимизировать=V} под{под=PR} конкретные{конкретный=A} потребности{потребность=S} пользователя{пользователь=S}
# В{в=PR} последние{последний=A} годы{год=S} российские{российский=A} любители{любитель=S} индийской{индийский=A} мудрости{мудрость=S} столкнулись{столкнуться=V} с{с=PR} немыслимым{немыслимый=A} в{в=PR} советские{советский=A} времена{время=S} изобилием{изобилие=S} печатной{печатный=A} продукции{продукция=S} по{по=PR} их{их=A} любимому{любимый=A} предмету{предмет=S}
# Идея{идея=S} о{о=PR} возможности{возможность=S} установления{установление=S} радиосвязи{радиосвязь=S} с{с=PR} другими{другой=A} мирами{мир=S} уже{уже=ADV} на{на=PR} современном{современный=A} уровне{уровень=S} радиофизики{радиофизика=S} недавно{недавно=ADV} стала{стать=V} реализоваться{реализоваться=V} на{на=PR} Национальной{национальный=A} радиоастрономической{радиоастрономический=A} обсерватории{обсерватория=S} в{в=PR} США{США=S}
# В{в=PR} последние{последний=A} годы{год=S} банки{банк=S} вдруг{вдруг=ADV} осознали{осознать=V} что{что=CONJ} указанный{указать=V} рынок{рынок=S} постепенно{постепенно=ADV} приобрел{приобрести=V} свойства{свойство=S} позволяющие{позволять=V} банковскому{банковский=A} бизнесу{бизнес=S} не{не=ADV} только{только=ADV} получить{получить=V} огромное{огромный=A} количество{количество=S} новых{новый=A} клиентов{клиент=S} но{но=CONJ} и{и=CONJ} совершить{совершить=V} настоящий{настоящий=A} прорыв{прорыв=S} в{в=PR} области{область=S} технологий{технология=S} банковского{банковский=A} обслуживания{обслуживание=S}
# Дедушка{дедушка=S} приканчивает{приканчивать=V} ближайшие{ближайший=A} заросли{зарасти=V} и{и=CONJ} теперь{теперь=ADV} дотягивается{дотягиваться=V} до{до=PR} новых{новый=A} но{но=CONJ} дотянуться{дотянуться=V} трудно{трудно=ADV} потому{потому=ADV} что{что=CONJ} склон{склон=S} крутой{крутой=A} сыпучий{сыпучий=A} и{и=CONJ} ногу{нога=S} негде{негде=NI} поставить{поставить=V}
# Это{это=NI} гораздо{гораздо=ADV} более{более=ADV} трудная{трудный=A} задача{задача=S} чем{чем=CONJ} локация{локация=S} Луны{луна=S} ибо{ибо=CONJ} как{как=ADV} известно{известно=NI} при{при=PR} радиолокации{радиолокация=S} необходима{необходимый=A} мощность{мощность=S} передатчика{передатчик=S} пропорциональная{пропорциональный=A} четвёртой{четвёртый=A} степени{степень=S} расстояния{расстояние=S} до{до=PR} лоцируемого{лоцируемый=A} объекта{объект=S}
